# %%
import face_recognition
import cv2

# Open the input movie file
input_movie = cv2.VideoCapture("test.mp4")

# Pull video metadata (length, fps, size) for re-use in output conversion
length = int(input_movie.get(cv2.CAP_PROP_FRAME_COUNT))
fps = input_movie.get(cv2.CAP_PROP_FPS)
size = (int(input_movie.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(input_movie.get(cv2.CAP_PROP_FRAME_HEIGHT)))

print(length,fps,size)

# Create an output movie file
# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# fourcc = cv2.VideoWriter_fourcc(*'X264')

fourcc = cv2.VideoWriter_fourcc(*'H264')
output_movie = cv2.VideoWriter('media/output.avi', fourcc, fps, size)
# output_movie = cv2.VideoWriter('media/output_stanley_sick_day_2.avi', fourcc, 30.007360, (1920, 1080))
# output_movie = cv2.VideoWriter('media/output_stanley4_a.avi', fourcc, 30.006912, (1920, 1080))


# Load some sample pictures and learn how to recognize them.
lmm_image = face_recognition.load_image_file("media/test.jpg")
lmm_face_encoding = face_recognition.face_encodings(lmm_image)[0]

al_image = face_recognition.load_image_file("media/test1.jpg")
al_face_encoding = face_recognition.face_encodings(al_image)[0]

known_faces = [
    lmm_face_encoding,
    al_face_encoding
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
frame_number = 0

while True:
    # Grab a single frame of video
    ret, frame = input_movie.read()
    frame_number += 1

    # Quit when the input video file ends
    if not ret:
        break

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_frame = frame[:, :, ::-1]

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    face_names = []
    for face_encoding in face_encodings:
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces(known_faces, face_encoding, tolerance=0.50)

        # If you had more than 2 faces, you could make this logic a lot prettier
        # but I kept it simple for the demo
        name = None
        if match[0]:
            name = "test"
        elif match[1]:
            name = "test1"

        face_names.append(name)

    # Label the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        if not name:
            continue

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 60), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 15), font, 1.8, (255, 255, 255), 1)

    # Write the resulting image to the output video file
    print("Writing frame {} / {}".format(frame_number, length))
    output_movie.write(frame)

# All done!
input_movie.release()
cv2.destroyAllWindows()

print('complete')
# Out:
# 53 29.78346112540273 (1920, 1080)
# Writing frame 1 / 53
# Writing frame 2 / 53
# Writing frame 3 / 53
# Writing frame 4 / 53
# Writing frame 5 / 53
# Writing frame 6 / 53
# Writing frame 7 / 53
# Writing frame 8 / 53
# Writing frame 9 / 53
# Writing frame 10 / 53
# Writing frame 11 / 53
# Writing frame 12 / 53
# Writing frame 13 / 53
# Writing frame 14 / 53
# Writing frame 15 / 53
# Writing frame 16 / 53
# Writing frame 17 / 53
# Writing frame 18 / 53
# Writing frame 19 / 53
# Writing frame 20 / 53
# Writing frame 21 / 53
# Writing frame 22 / 53
# Writing frame 23 / 53
# Writing frame 24 / 53
# Writing frame 25 / 53
# Writing frame 26 / 53
# Writing frame 27 / 53
# Writing frame 28 / 53
# Writing frame 29 / 53
# Writing frame 30 / 53
# Writing frame 31 / 53
# Writing frame 32 / 53
# Writing frame 33 / 53
# Writing frame 34 / 53
# Writing frame 35 / 53
# Writing frame 36 / 53
# Writing frame 37 / 53
# Writing frame 38 / 53
# Writing frame 39 / 53
# Writing frame 40 / 53
# ...
